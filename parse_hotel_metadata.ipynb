# %%
import csv
import pandas as pd
import itertools as it

# %%
file_name = 'data_sample/hotels_sample_metadata.csv'
df = pd.read_csv(file_name, sep = ',')

# %%
df['metadata'] = df.apply(lambda row: row.metadata.replace(' ','').strip('|').split('|'), axis=1)

# %%
# Get all categories
l=list(df['metadata'])
flat_list = [item for l in l for item in l]

# %%
l=list(df['metadata'])
flat_list = [item for l in l for item in l]

# %%
df
# Out:
#     AccomodationId  PictureId  \
# 0          2447106          0
# 1          2447106          1
# 2          2447106         10
# 3          2447106         11
# 4          2447106         12
# 5          2447106         13
# 6          2447106         14
# 7          2447106         15
# 8          2447106         16
# 9          2447106         17
# 10         2447106         18
# 11         2447106         19
# 12         2447106          2
# 13         2447106         20
# 14         2447106         21
# 15         2447106         22
# 16         2447106         23
# 17         2447106         24
# 18         2447109          0
# 19         2447109          1
# 20         2447109         10
# 21         2447109         11
# 22         2447109         12
# 23         2447109         13
# 24         2447109         14
# 25         2447109         15
# 26         2447109         16
# 27         2447109         17
# 28         2447109         18
# 29         2447109          2
# ...
